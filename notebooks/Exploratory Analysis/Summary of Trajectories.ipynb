# %% [markdown]
# # Load packages and data

# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryTrajectories import SummaryTrajectories
import matplotlib.pyplot as plt
#import pandas as pd
#import datetime

# Use the SummaryTrajectories class
fig_size = (12, 6)
summary_file = "RegionAll_01042019_31032020_FishCargTank_600_315569220_60_trajectories_summary_1.csv"
summary_trajectories = SummaryTrajectories(summary_file, save_figures=True, plot_figures=True,
                                           fig_size=fig_size, date="DateTimeStart")
df = summary_trajectories.df
df.sample(n=2)
# Out:
#                           MMSI ShipType  TrackLength  MeanSpeed  \
# DateTime
# 2020-02-27 06:12:46  211247580    Cargo          926   9.576764
# 2019-06-17 03:45:59  261002370  Fishing           58   0.000000
#
#                                      DateTimeStart  \
# DateTime
# 2020-02-27 06:12:46  2020-02-27 06:12:46.000000000
# 2019-06-17 03:45:59  2019-06-17 03:45:59.000000000
#
#                                        DateTimeEnd   StartLat     EndLat  \
# DateTime
# 2020-02-27 06:12:46  2020-02-27 21:37:46.000000000  57.865052  57.068418
# 2019-06-17 03:45:59  2019-06-17 04:42:59.000000000  54.177947  54.177965
#
#                       StartLon     EndLon                   DateTimeMean  \
# DateTime
# 2020-02-27 06:12:46   8.733518   9.974420  2020-02-27 13:55:16.000000256
# 2019-06-17 03:45:59  15.556810  15.556828  2019-06-17 04:14:29.000000256
#
#                      Month Weekday Name  Day of Month
# DateTime
# 2020-02-27 06:12:46      2     Thursday            27
# 2019-06-17 03:45:59      6       Monday            17

# %%
# Basic data exploration
summary_trajectories.basic_statistics(resample_frequency=60)
# Out:
# Number of Trajectories: 272589
# Number of AIS message updates: 318388019
# Number of unique MMSIs: 9269
#
# Number of unique MMSIs by ShipType
# Cargo      5742
# Fishing    1182
# Tanker     2345
# Name: MMSI, dtype: int64
#
# Mean speed by ShipType
# Cargo      9.981612
# Fishing    2.731997
# Tanker     9.285020
# Name: MeanSpeed, dtype: float64
#
# Number of trajectories by ShipType
# Cargo      146576
# Fishing     63285
# Tanker      62728
# Name: ShipType, dtype: int64
#
# Summary statistics for track length in minutes:
# count    272589.000000
# mean       1168.014920
# std        5054.635284
# min          11.000000
# 25%          91.000000
# 50%         370.000000
# 75%        1172.000000
# max      236160.000000
# Name: TrackLength, dtype: float64

# %%
df.sort_values("DateTimeStart")
# Out:
#                           MMSI ShipType  TrackLength  MeanSpeed  \
# DateTime
# 2019-04-01 00:00:00  245457000    Cargo         2539   2.823106
# 2019-04-01 00:00:00  209284000    Cargo         5017   1.432001
# 2019-04-01 00:00:00  246620000    Cargo          938   8.429112
# 2019-04-01 00:00:00  265581970   Tanker        20055   1.691549
# 2019-04-01 00:00:00  246684000    Cargo          294   8.765822
# ...                        ...      ...          ...        ...
# 2020-03-31 23:42:24  266273000   Tanker           18   0.018957
# 2020-03-31 23:42:40  266235000   Tanker           18   5.086138
# 2020-03-31 23:44:36  538008326   Tanker           16  12.750521
# 2020-03-31 23:45:55  564446000    Cargo           15   4.677339
# 2020-03-31 23:46:00  266068000  Fishing           14   7.601786
#
#                                      DateTimeStart  \
# DateTime
# 2019-04-01 00:00:00  2019-04-01 00:00:00.000000000
# 2019-10-20 00:00:02     10       Sunday            20
# 2019-10-20 00:00:04     10       Sunday            20

# %%
# Search for a specific MMSI
mmsi = 219011018
df.loc[df["MMSI"] == mmsi]
# Out:
#                           MMSI ShipType  TrackLength  MeanSpeed  \
# DateTime
# 2019-04-01 00:00:11  219011018  Fishing        83102   0.657501
# 2019-05-29 00:00:03  219011018  Fishing        13721   1.222497
# 2019-06-08 00:00:02  219011018  Fishing       100800   0.893673
# 2019-08-18 00:00:00  219011018  Fishing        90303   0.980190
# 2019-10-20 00:00:02  219011018  Fishing       236160   0.454570
#
#                                      DateTimeStart  \
# DateTime
# 2019-04-01 00:00:11  2019-04-01 00:00:11.000000000
# 2019-05-29 00:00:03  2019-05-29 00:00:03.000000000
# 2019-06-08 00:00:02  2019-06-08 00:00:02.000000000
# 2019-08-18 00:00:00  2019-08-18 00:00:00.000000000
# 2019-10-20 00:00:02  2019-10-20 00:00:02.000000000
#
#                                        DateTimeEnd   StartLat     EndLat  \
# DateTime
# 2019-04-01 00:00:11  2019-05-28 17:01:11.000000000  54.911244  57.593673
# 2019-05-29 00:00:03  2019-06-07 12:40:03.000000000  57.593675  57.593650
# 2019-06-08 00:00:02  2019-08-16 23:59:02.000000000  57.593664  57.593650
# 2019-08-18 00:00:00  2019-10-19 17:02:00.000000000  57.593783  57.593650
# 2019-10-20 00:00:02  2020-03-31 23:59:02.000000000  57.593650  57.594283
#
#                      StartLon    EndLon                   DateTimeMean  Month  \
# DateTime
# 2019-04-01 00:00:11  9.610433  9.958953  2019-04-29 20:30:40.999999488      4
# 2019-05-29 00:00:03  9.958967  9.958950  2019-06-02 18:20:03.000000256      5
# 2019-06-08 00:00:02  9.958950  9.958967  2019-07-12 23:59:32.000000256      6
# 2019-08-18 00:00:00  9.959350  9.958950  2019-09-18 08:30:59.999999744      8
# 2019-10-20 00:00:02  9.958950  9.958271  2020-01-09 23:59:31.999998720     10
#
#                     Weekday Name  Day of Month
# DateTime
# 2019-04-01 00:00:11       Monday             1
# 2019-05-29 00:00:03    Wednesday            29
# 2019-06-08 00:00:02     Saturday             8
# 2019-08-18 00:00:00       Sunday            18
# 2019-10-20 00:00:02       Sunday            20

# %%
# Search for a specific MMSI
mmsi = 219905000
df.loc[df["MMSI"] == mmsi]
# Out:
#                           MMSI ShipType  TrackLength  MeanSpeed  \
# DateTime
# 2019-05-02 15:19:24  219905000  Fishing        37543   0.004780
# 2019-05-29 00:00:05  219905000  Fishing        13721   0.004993
# 2019-06-08 00:00:04  219905000  Fishing       100800   0.004873
# 2019-08-18 00:00:04  219905000  Fishing        90303   0.005558
# 2019-10-20 00:00:04  219905000  Fishing       236160   0.005724
#
#                                      DateTimeStart  \
# DateTime
# 2019-05-02 15:19:24  2019-05-02 15:19:24.000000000
# 2019-05-29 00:00:05  2019-05-29 00:00:05.000000000
# 2019-06-08 00:00:04  2019-06-08 00:00:04.000000000
# 2019-08-18 00:00:04  2019-08-18 00:00:04.000000000
# 2019-10-20 00:00:04  2019-10-20 00:00:04.000000000
#
#                                        DateTimeEnd   StartLat     EndLat  \
# DateTime
# 2019-05-02 15:19:24  2019-05-28 17:01:24.000000000  55.262204  55.262181
# 2019-05-29 00:00:05  2019-06-07 12:40:05.000000000  55.262185  55.262200
# 2019-06-08 00:00:04  2019-08-16 23:59:04.000000000  55.262200  55.262189
# 2019-08-18 00:00:04  2019-10-19 17:02:04.000000000  55.262177  55.262188
# 2019-10-20 00:00:04  2020-03-31 23:59:04.000000000  55.262158  55.262171
#
#                      StartLon    EndLon                   DateTimeMean  Month  \
# DateTime
# 2019-05-02 15:19:24  9.711835  9.711833  2019-05-15 16:10:24.000000000      5
# 2019-05-29 00:00:05  9.711820  9.711876  2019-06-02 18:20:05.000000000      5
# 2019-06-08 00:00:04  9.711830  9.711804  2019-07-12 23:59:34.000000512      6
# 2019-08-18 00:00:04  9.711802  9.711790  2019-09-18 08:31:04.000000256      8
# 2019-10-20 00:00:04  9.711798  9.711803  2020-01-09 23:59:34.000000768     10
#
#                     Weekday Name  Day of Month
# DateTime
# 2019-05-02 15:19:24     Thursday             2
# 2019-05-29 00:00:05    Wednesday            29
# 2019-06-08 00:00:04     Saturday             8
# 2019-08-18 00:00:04       Sunday            18
# 2019-10-20 00:00:04       Sunday            20

# %% [markdown]
# # Visualising distributions

# %%
# Plot the trajectory count for each ship type
summary_trajectories.hist_bar_plot(df["ShipType"].value_counts().reset_index(name="counts"),
                                   "Bar", "counts", "index", file_name="trajectory_count_by_shipType",
                                   xlabel="Trajectory Count", ylabel="Ship Type")

# Plot the number of unique MMSIs for each ship type
data = df.groupby("ShipType")["MMSI"].nunique().reset_index(name="counts").sort_values("counts", ascending=False)
summary_trajectories.hist_bar_plot(data, "Bar", "counts", "ShipType", file_name="unique_MMSIs_count_by_shipType",
                                   xlabel="Unique MMSIs", ylabel="Ship Type")

# %%
# Plot the mean speed histogram for each ship type
df_hist = df.reset_index()
hue_order = ["Cargo", "Tanker", "Fishing"]
summary_trajectories.hist_bar_plot(df_hist, "Histogram", "MeanSpeed", 
                                   file_name="mean_speed_histogram_by_shipType", xlabel="Mean speed",
                                   hue="ShipType", hue_order=hue_order, xlim=[-1, 22])

# Plot the mean speed histogram for cargo and tankers
summary_trajectories.hist_bar_plot(df_hist.loc[df_hist["ShipType"] != "Fishing"], 
                                   "Histogram", "MeanSpeed", xlabel="Mean speed",
                                   hue="ShipType", hue_order=["Cargo", "Tanker"], xlim=[-1, 22])

# %%
# Plot the mean speed histogram for each ship type as three subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5))
df.loc[df["ShipType"] == "Fishing"]['MeanSpeed'].plot.hist(ax=ax1, bins=50) 
ax1.set_xlabel('Mean speed for fishing vessels')
ax1.set_ylabel('Number of Trajectories')
ax1.set_xlim(0, 11)
df.loc[df["ShipType"] == "Cargo"]['MeanSpeed'].plot.hist(ax=ax2, bins=50) 
ax2.set_xlabel('Mean speed for cargo vessels')
ax2.set_ylabel('Number of Trajectories')
ax2.set_xlim(0, 25)
df.loc[df["ShipType"] == "Tanker"]['MeanSpeed'].plot.hist(ax=ax3, bins=50) 
ax3.set_xlabel('Mean speed for tankers')
ax3.set_ylabel('Number of Trajectories')
ax3.set_xlim(0, 20)
plt.show()

# %%
# Plot trajectory length counts for each ship type
summary_trajectories.hist_bar_plot(df_hist, "Histogram", "TrackLength",
                                   xlabel="Track length", hue="ShipType", hue_order=hue_order)

# Plot trajectory length counts for each ship type - Zoomed in more
summary_trajectories.hist_bar_plot(df_hist, "Histogram", "TrackLength", 
                                   file_name="trajectory_length_counts_histogram_by_shipType", 
                                   xlabel="Track length", hue="ShipType", hue_order=hue_order, xlim=[0, 3000])

# %%
# Look at the mean track length by day of month
mean_track_length = df.groupby('Day of Month')['TrackLength'].mean().reset_index(name='Mean track length')
summary_trajectories.hist_bar_plot(mean_track_length, "Bar", x="Day of Month", y="Mean track length")

# Plot the median track length by day of month
median_track_length = df.groupby('Day of Month')['TrackLength'].median().reset_index(name='Median track length')
summary_trajectories.hist_bar_plot(median_track_length, "Bar", x="Day of Month", y="Median track length")

# %% [markdown]
# # Visualising time series data

# %%
# Look at some basic time series analysis based on daily trajectory count grouped by ShipType
df_date_type = summary_trajectories.df_date_type
df_date_type.sample(n=3)
# Out:
# ShipType    Cargo  Fishing  Tanker  Month Weekday Name
# DateTime
# 2019-12-12    318       99     131     12     Thursday
# 2019-08-25    587      382     251      8       Sunday
# 2020-01-06    375      126     163      1       Monday

# %%
# Plot the daily trajectory count for each ship type 
summary_trajectories.time_series_line_plot(df_date_type[["Cargo", "Tanker", "Fishing"]], 
                                           "Pandas", file_name="daily_trajectory_count_by_shipType",
                                           xlabel="Date", ylabel="Daily Trajectory Count")

# Plot the daily trajectory count for fishing vessels 
summary_trajectories.time_series_line_plot(df_date_type[["Fishing"]], "Pandas", 
                                           file_name="daily_trajectory_count_fishing",
                                           xlabel="Date", ylabel="Daily Trajectory Count")

# %%
# Zoom in on June-September and show fishing vessels with the weekday name
df_zoom = df_date_type.loc[df_date_type["Month"].isin([6, 7, 8, 9])]
summary_trajectories.time_series_line_plot(df_zoom, "Seaborn", x=df_zoom.index, y="Fishing", 
                                           file_name="daily_trajectory_count_fishing_June_August",
                                           xlabel="Date", ylabel="Daily Trajectory Count", include_points=True)

# Zoom in on October-December and show fishing vessels with the weekday name
df_zoom = df_date_type.loc[df_date_type["Month"].isin([10, 11, 12])]
summary_trajectories.time_series_line_plot(df_zoom, "Seaborn", x=df_zoom.index, y="Fishing", 
                                           file_name="daily_trajectory_count_fishing_June_August",
                                           xlabel="Date", ylabel="Daily Trajectory Count", include_points=True)

# %%
# Further explore the seasonality of the data with box plots to display the distributions for each group.
# First group the data by month to visualize yearly seasonality
summary_trajectories.fig_size = (16, 12)
summary_trajectories.box_plot(df_date_type, x="Month", ylabel="Trajectory Count",
                              file_name="daily_trajectory_count_by_shipType_month")

# Group the data by weekday to visualize weekly fluctuations
summary_trajectories.box_plot(df_date_type, x="Weekday Name", ylabel="Trajectory Count",
                              file_name="daily_trajectory_count_by_shipType_weekday")

# %%
# Take a look at mean speed - First group the data by month to visualize yearly seasonality
summary_trajectories.box_plot(df, x="Month", y="MeanSpeed", ylabel="Mean speed",
                              file_name="meanSpeed_by_shipType_month")

# Take a look at mean speed - Group the data by weekday to visualize weekly fluctuations
summary_trajectories.box_plot(df, x="Weekday Name", y="MeanSpeed", ylabel="Mean speed",
                              file_name="meanSpeed_by_Weekday")
