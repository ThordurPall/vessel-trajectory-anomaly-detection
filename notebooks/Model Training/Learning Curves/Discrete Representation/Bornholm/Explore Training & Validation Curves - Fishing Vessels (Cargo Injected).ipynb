# %% [markdown]
# # Load packages and define useful functions

# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryModels import SummaryModels
import pandas as pd

# %%
# Use the SummaryModels class
level = "Step"
ylims = [(4, 30), (0, 1), (-30, -4)]
file_name = "RegionBornholm_01062019_30092019_Fish_14400_86400_600"
summary_models = SummaryModels(file_name)
setup_type = "Default"
df_default = summary_models.load_curves_df(setup_type)
df_default_step = summary_models.load_curves_df(setup_type, level=level)
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=ylims)

# %% [markdown]
# ### Trajectory based reconstruction log probabilities
# Plot histograms of the validation trajectory based reconstruction log probabilities

# %%
summary_models = SummaryModels(file_name)
data_track_based = summary_models.run_evaluation(setup_type=setup_type)["TrajectoryLevelData"]
x = "Reconstruction log probability"

# Plot trajectory based reconstruction log probabilities
summary_models.hist_stacked_plot(data_track_based, type="Histogram", x=x, print_summary_stats=True)
# Out:
# C:\Github\vessel-trajectory-anomaly-detection\models\saved-models\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse.pth
# Mean Reconstruction log probability: -1145.4482296673598
# Median Reconstruction log probability: -948.2752075195312
# Reconstruction log probability statistics by ship type:
#            count        mean         std          min          25%  \
# Ship type
# Fishing    113.0 -1145.44823  794.488025 -4113.298828 -1494.371826
#
#                   50%         75%       max
# Ship type
# Fishing   -948.275208 -596.398132 -5.941392

# %% [markdown]
# ### Equally weighted (point based) reconstruction log probabilities
# Divide the trajectory based reconstruction log probabilities by the corresponding trajectory length and plot the same histograms as above

# %%
x = "Equally weighted reconstruction log probability"
summary_models.hist_stacked_plot(data_track_based, type="Histogram", x=x, print_summary_stats=True)
# Out:
# Mean Equally weighted reconstruction log probability: -12.141405789617028
# Median Equally weighted reconstruction log probability: -11.552219935825892
# Equally weighted reconstruction log probability statistics by ship type:
#            count       mean       std       min        25%       50%  \
# Ship type
# Fishing    113.0 -12.141406  9.935952 -61.01544 -16.231482 -11.55222
#
#                 75%      max
# Ship type
# Fishing   -4.282328 -0.04401

# %% [markdown]
# # Look at the default setup - Injected Proportion = 0.05
# Use the VRNN model, 100 dimensional latent and recurrent laten space, and no batch normalization, scheduler, or KL annealing.

# %%
# Use the SummaryModels class
inject_cargo_proportion = 0.05
summary_models_005 = SummaryModels(file_name, inject_cargo_proportion=inject_cargo_proportion)
setup_type = "Default 0.05"
df_default_005 = summary_models_005.load_curves_df(setup_type)
df_default_005_step = summary_models_005.load_curves_df(setup_type, level=level)
summary_models_005.plot_curves(df_default_005)
summary_models_005.plot_curves(df_default_005, ylims=ylims)

# %% [markdown]
# ### Trajectory based reconstruction log probabilities
# Plot histograms of the validation trajectory based reconstruction log probabilities

# %%
summary_models_005 = SummaryModels(file_name)
data_track_based_005 = summary_models_005.run_evaluation(setup_type=setup_type)["TrajectoryLevelData"]
x = "Reconstruction log probability"

# Plot trajectory based reconstruction log probabilities
summary_models.hist_stacked_plot(data_track_based_005, type="Histogram", x=x, print_summary_stats=True)
# Out:
# C:\Github\vessel-trajectory-anomaly-detection\models\saved-models\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse.pth
# Mean Reconstruction log probability: -1145.0190459183887
# Median Reconstruction log probability: -947.0735473632812
# Reconstruction log probability statistics by ship type:
#            count         mean      std          min          25%         50%  \
# Ship type
# Fishing    113.0 -1145.019046  793.575 -4112.353027 -1493.812622 -947.073547
#
#                   75%       max
# Ship type
# Fishing   -595.589478 -6.230077

# %% [markdown]
# ### Equally weighted (point based) reconstruction log probabilities
# Divide the trajectory based reconstruction log probabilities by the corresponding trajectory length and plot the same histograms as above

# %%
x = "Equally weighted reconstruction log probability"
summary_models_005.hist_stacked_plot(data_track_based_005, type="Histogram", x=x, print_summary_stats=True)
# Out:
# Mean Equally weighted reconstruction log probability: -12.137780071323053
# Median Equally weighted reconstruction log probability: -11.542129516601562
# Equally weighted reconstruction log probability statistics by ship type:
#            count      mean       std        min        25%       50%  \
# Ship type
# Fishing    113.0 -12.13778  9.934997 -61.098814 -16.236031 -11.54213
#
#                 75%       max
# Ship type
# Fishing   -4.275356 -0.046149

# %% [markdown]
# # Look at the default setup - Injected Proportion = 0.1
# Use the VRNN model, 100 dimensional latent and recurrent laten space, and no batch normalization, scheduler, or KL annealing.

# %%
# Use the SummaryModels class
inject_cargo_proportion = 0.1
summary_models_01 = SummaryModels(file_name, inject_cargo_proportion=inject_cargo_proportion)
setup_type = "Default 0.1"
df_default_01 = summary_models_01.load_curves_df(setup_type)
df_default_01_step = summary_models_01.load_curves_df(setup_type, level=level)
summary_models_01.plot_curves(df_default_01)
summary_models_01.plot_curves(df_default_01, ylims=ylims)
data_track_based_01 = summary_models_01.run_evaluation(setup_type=setup_type)["TrajectoryLevelData"]
# Out:
# C:\Github\vessel-trajectory-anomaly-detection\models\saved-models\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_Injected01_latent100_recurrent100_batchNormFalse.pth

# %% [markdown]
# # Look at the default setup - Injected Proportion = 0.2
# Use the VRNN model, 100 dimensional latent and recurrent laten space, and no batch normalization, scheduler, or KL annealing.

# %%
# Use the SummaryModels class
inject_cargo_proportion = 0.2
summary_models_02 = SummaryModels(file_name, inject_cargo_proportion=inject_cargo_proportion)
setup_type = "Default 0.2"
df_default_02 = summary_models_02.load_curves_df(setup_type)
df_default_02_step = summary_models_02.load_curves_df(setup_type, level=level)
summary_models_02.plot_curves(df_default_02)
summary_models_02.plot_curves(df_default_02, ylims=ylims)
data_track_based_02 = summary_models_02.run_evaluation(setup_type=setup_type)["TrajectoryLevelData"]
# Out:
# C:\Github\vessel-trajectory-anomaly-detection\models\saved-models\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_Injected02_latent100_recurrent100_batchNormFalse.pth

# %% [markdown]
# # Look at the default setup - Injected Proportion = 0.5
# Use the VRNN model, 100 dimensional latent and recurrent laten space, and no batch normalization, scheduler, or KL annealing.

# %%
# Use the SummaryModels class
inject_cargo_proportion = 0.5
summary_models_05 = SummaryModels(file_name, inject_cargo_proportion=inject_cargo_proportion)
setup_type = "Default 0.5"
df_default_05 = summary_models_05.load_curves_df(setup_type)
df_default_05_step = summary_models_05.load_curves_df(setup_type, level=level)
summary_models_05.plot_curves(df_default_05)
summary_models_05.plot_curves(df_default_05, ylims=ylims)
data_track_based_05 = summary_models_05.run_evaluation(setup_type=setup_type)["TrajectoryLevelData"]
# Out:
# C:\Github\vessel-trajectory-anomaly-detection\models\saved-models\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_Injected05_latent100_recurrent100_batchNormFalse.pth

# %% [markdown]
# # Look at the default setup - Injected Proportion = 1.0
# Use the VRNN model, 100 dimensional latent and recurrent laten space, and no batch normalization, scheduler, or KL annealing.

# %%
# Use the SummaryModels class
inject_cargo_proportion = 1.0
summary_models_10 = SummaryModels(file_name, inject_cargo_proportion=inject_cargo_proportion)
setup_type = "Default 1.0"
df_default_10 = summary_models_10.load_curves_df(setup_type)
df_default_10_step = summary_models_10.load_curves_df(setup_type, level=level)
summary_models_10.plot_curves(df_default_10)
summary_models_10.plot_curves(df_default_10, ylims=ylims)
data_track_based_10 = summary_models_10.run_evaluation(setup_type=setup_type)["TrajectoryLevelData"]
# Out:
# C:\Github\vessel-trajectory-anomaly-detection\models\saved-models\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_Injected10_latent100_recurrent100_batchNormFalse.pth

# %% [markdown]
# # Look at the default setup - Injected Proportion = 2.0
# Use the VRNN model, 100 dimensional latent and recurrent laten space, and no batch normalization, scheduler, or KL annealing.

# %%
# Use the SummaryModels class
inject_cargo_proportion = 2.0
summary_models_20 = SummaryModels(file_name, inject_cargo_proportion=inject_cargo_proportion)
setup_type = "Default 2.0"
df_default_20 = summary_models_20.load_curves_df(setup_type)
df_default_20_step = summary_models_20.load_curves_df(setup_type, level=level)
summary_models_20.plot_curves(df_default_20)
summary_models_20.plot_curves(df_default_20, ylims=ylims)
data_track_based_20 = summary_models_20.run_evaluation(setup_type=setup_type)["TrajectoryLevelData"]
# Out:
# C:\Github\vessel-trajectory-anomaly-detection\models\saved-models\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_Injected20_latent100_recurrent100_batchNormFalse.pth

# %% [markdown]
# # Comparison - Epoch Level

# %%
df = pd.concat([df_default, df_default_005, df_default_01, df_default_02, df_default_05, df_default_10, df_default_20])
df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = ["Default", "Default 0.05", "Default 0.1", "Default 0.2", "Default 0.5", "Default 1.0", "Default 2.0"]
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set")
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set")
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           ylims=ylims)
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           ylims=ylims)

# %% [markdown]
# # Comparison - Optimizer Steps Level

# %%
df_step = pd.concat([df_default_step, df_default_005_step, df_default_01_step, df_default_02_step, df_default_05_step, 
                     df_default_10_step, df_default_20_step])
df_step.reset_index(drop=True, inplace=True)
hue = "Setup type"
x = "Number of optimiser steps"
hue_order = ["Default", "Default 0.05", "Default 0.1", "Default 0.2", "Default 0.5", "Default 1.0", "Default 2.0"]
summary_models.plot_curves(df_step[df_step["Data set type"] == "Training"], hue, hue_order, title="Training data set", x=x)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Validation"], hue, hue_order, title="Validation data set", x=x)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           x=x, ylims=ylims)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           x=x, ylims=ylims)

# %%
# Combine the different proportion date frames
df_rec = pd.concat([data_track_based, data_track_based_005, data_track_based_01, data_track_based_02,
                   data_track_based_05, data_track_based_10, data_track_based_20])
df_rec.reset_index(drop=True, inplace=True)

# Plot trajectory based reconstruction log probabilities for fishing vessels
title = "Trajectory based reconstruction log probabilities - Trained on different types comparison"
x = "Reconstruction log probability"
summary_models.hist_stacked_plot(df_rec, type="Histogram", title=title, x=x, hue=hue, hue_order=hue_order)
summary_models.hist_stacked_plot(df_rec, type="Stacked", x=x, hue=hue, title=title, hue_order=hue_order, stat="proportion")
summary_models.hist_stacked_plot(df_rec, type="Stacked", x=x, title=title, hue=hue, hue_order=hue_order,
                                 stat="normalized_largest", ylabel="Count (divided by largest count)")
print(df_rec.groupby(hue)[x].describe())

# Plot equally weighted (point based) reconstruction log probabilities for fishing vessels
title = "Equally weighted (point based) reconstruction log probabilities - Trained on different types comparison"
x = "Equally weighted reconstruction log probability"
summary_models.hist_stacked_plot(df_rec, type="Histogram", title=title, x=x, hue=hue, hue_order=hue_order)
summary_models.hist_stacked_plot(df_rec, type="Stacked", x=x, hue=hue, title=title, hue_order=hue_order, stat="proportion")
summary_models.hist_stacked_plot(df_rec, type="Stacked", x=x, title=title, hue=hue, hue_order=hue_order,
                                 stat="normalized_largest", ylabel="Count (divided by largest count)")
df_rec.groupby(hue)[x].describe()
# Out:
#               count         mean         std          min          25%  \
# Setup type
# Default       113.0 -1145.448230  794.488025 -4113.298828 -1494.371826
# Default 0.05  113.0 -1145.019046  793.575000 -4112.353027 -1493.812622
# Default 0.1   113.0 -1014.559291  644.884128 -3258.087402 -1295.043213
# Default 0.2   113.0  -930.778732  552.385644 -2780.482422 -1235.736328
# Default 0.5   113.0  -823.864064  443.248750 -2100.142822 -1106.015137
# Default 1.0   113.0  -793.857477  406.780991 -1902.033691 -1043.918823
# Default 2.0   113.0  -767.360082  401.543656 -2066.731934  -994.530273
#
#                      50%         75%        max
# Setup type
# Default      -948.275208 -596.398132  -5.941392
# Default 0.05 -947.073547 -595.589478  -6.230077
# Default 0.1  -829.200012 -579.831604  -5.365601
# Default 0.2  -790.351501 -590.736511 -11.385126
# Default 0.5  -683.937683 -577.995850 -12.164591
# Default 1.0  -667.744873 -588.189087  -8.197020
# ...

# %% [markdown]
# #  Compare Default and 200% Cargo/Tankers

# %%
df_step = pd.concat([df_default_step, df_default_20_step])
df_step.reset_index(drop=True, inplace=True)
hue = "Setup type"
x = "Number of optimiser steps"
hue_order = ["Default", "Default 2.0"]
summary_models.plot_curves(df_step[df_step["Data set type"] == "Training"], hue, hue_order, title="Training data set", x=x)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Validation"], hue, hue_order, title="Validation data set", x=x)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           x=x, ylims=ylims)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           x=x, ylims=ylims)

# %%
data_track_based
# Out:
#      Data set Index    Index       MMSI Ship type  Length  \
# 0                 0  4982341  265681420   Fishing     135
# 1                 1  4547326  261061000   Fishing      31
# 2                 2   295372  211314800   Fishing     124
# 3                 3  4773692  265551874   Fishing     138
# 4                 4  2259131  230069190   Fishing     141
# ..              ...      ...        ...       ...     ...
# 108             108  5724845  265750000   Fishing     139
# 109             109   609266  211474000   Fishing     134
# 110             110   155071  211314800   Fishing     126
# 111             111  1782032  220353000   Fishing     140
# 112             112  3451602  261003230   Fishing      75
#
#      Reconstruction log probability  \
# 0                       -497.383789
# 1                       -666.898438
# 2                      -4113.298828
# 3                      -1047.379150
# 4                       -596.398132
# ..                              ...
# ...

# %%
data_track_based_20
# Out:
#      Data set Index    Index       MMSI Ship type  Length  \
# 0                 0  4982341  265681420   Fishing     135
# 1                 1  4547326  261061000   Fishing      31
# 2                 2   295372  211314800   Fishing     124
# 3                 3  4773692  265551874   Fishing     138
# 4                 4  2259131  230069190   Fishing     141
# ..              ...      ...        ...       ...     ...
# 108             108  5724845  265750000   Fishing     139
# 109             109   609266  211474000   Fishing     134
# 110             110   155071  211314800   Fishing     126
# 111             111  1782032  220353000   Fishing     140
# 112             112  3451602  261003230   Fishing      75
#
#      Reconstruction log probability  \
# 0                       -505.917633
# 1                       -424.766052
# 2                      -1620.173340
# 3                       -925.696411
# 4                       -611.354126
# ..                              ...
# ...

# %% [markdown]
# # Look at the default setup - Trained over one year
# Use the VRNN model, 100 dimensional latent and recurrent laten space, and no batch normalization, scheduler, or KL annealing.

# %%
# Use the SummaryModels class
level = "Step"
ylims = [(4, 30), (0, 1), (-30, -4)]
file_name = "RegionBornholm_01042019_31032020_Fish_14400_86400_600"
summary_models_year = SummaryModels(file_name)
setup_type = "Default 1Year"
df_default_year = summary_models_year.load_curves_df(setup_type)
df_default_step_year = summary_models_year.load_curves_df(setup_type, level=level)
summary_models_year.plot_curves(df_default_year)
summary_models_year.plot_curves(df_default_year, ylims=ylims)

# %%
df_step = pd.concat([df_default_step, df_default_005_step, df_default_01_step, df_default_02_step, df_default_05_step, 
                     df_default_10_step, df_default_20_step, df_default_step_year])
df_step.reset_index(drop=True, inplace=True)
hue = "Setup type"
x = "Number of optimiser steps"
hue_order = ["Default", "Default 0.05", "Default 0.1", "Default 0.2", "Default 0.5", "Default 1.0", "Default 2.0", "Default 1Year"]
summary_models.plot_curves(df_step[df_step["Data set type"] == "Training"], hue, hue_order, title="Training data set", x=x)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Validation"], hue, hue_order, title="Validation data set", x=x)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           x=x, ylims=ylims)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           x=x, ylims=ylims)

# %% [markdown]
# #  Compare Default,  200% Cargo/Tankers, and One Year

# %%
df_step = pd.concat([df_default_step, df_default_20_step, df_default_step_year])
df_step.reset_index(drop=True, inplace=True)
hue = "Setup type"
x = "Number of optimiser steps"
hue_order = ["Default", "Default 2.0", "Default 1Year"]
summary_models.plot_curves(df_step[df_step["Data set type"] == "Training"], hue, hue_order, title="Training data set", x=x)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Validation"], hue, hue_order, title="Validation data set", x=x)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           x=x, ylims=ylims)
summary_models.plot_curves(df_step[df_step["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           x=x, ylims=ylims)
