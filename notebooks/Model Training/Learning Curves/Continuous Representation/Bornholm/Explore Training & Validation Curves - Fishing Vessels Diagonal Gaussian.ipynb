# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryModels import SummaryModels
import pandas as pd
file_name = "RegionBornholm_01062019_30092019_Fish_14400_86400_600"

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# # Run 1: Epoch 500 - First milestone with gamma = 0.5 or 0.6

# %% [markdown]
# ## Gamma = 0.9

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.8

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.7

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.6

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.5 - Use this or gamma = 0.6

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# # Run 1: Epoch 700 - (Second milestone with gamma =  0.5 or 0.6 or 0.7)

# %% [markdown]
# ## Gamma = 0.9

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.8

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.5 - Use this or gamma = 0.6

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# # Run 1: Epoch 1000 - (Third milestone with gamma =  0.7 or 0.5 or 0.6)

# %% [markdown]
# ## Gamma = 0.7

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.6

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.5 - Use this or gamma = 0.6

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.7
scheduler_milestones = [500, 700, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [500, 700, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.7
scheduler_milestones = [450, 550, 700, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [450, 550, 700, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.75
scheduler_milestones = [400, 600, 800, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [400, 600, 800, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.65
scheduler_milestones = [500, 700, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [500, 700, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.65
scheduler_milestones = [450, 550, 700, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [500, 700, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.6
scheduler_milestones = [500, 700, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [500, 700, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.5
scheduler_milestones = [500, 700, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [500, 700, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.75
scheduler_milestones = [400, 600, 800, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [400, 600, 800, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00003
scheduler_gamma = [0.8, 0.5, 0.6, 0.6]
scheduler_milestones = [650, 850, 1050, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [650, 850, 1050, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00005
scheduler_gamma = [0.5, 0.5, 0.7, 0.6]
scheduler_milestones = [500, 700, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [500, 700, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])
