# %% [markdown]
# # Load packages

# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryModels import SummaryModels
import pandas as pd
file_name = "RegionBornholm_01062019_30092019_Fish_14400_86400_600"

# %% [markdown]
# # Look at the default setup
# Use the VRNN model, 100 dimensional latent and recurrent laten space, and no batch normalization, scheduler, or KL annealing. Showing results for fishing, cargo and tanker vessels

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.0001
scheduler_gamma = 0.998
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.0001, Gamma: 0.998")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(15, 40), (0, 10), (-40, -15)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.0001
scheduler_gamma = 0.99
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.0001, Gamma: 0.99")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(15, 40), (0, 10), (-40, -15)])

# %%
scheduler_milestones = [1, 5, 7]
''.join([str(i) for i in scheduler_milestones])
# Out:
# '157'

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.0001
scheduler_gamma = 0.985
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.0001, Gamma: 0.985")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(15, 40), (0, 10), (-40, -15)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.0001
scheduler_gamma = 0.9
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.0001, Gamma: 0.9")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(15, 400), (0, 10), (-400, -15)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.001
scheduler_gamma = 0.993
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.001, Gamma: 0.993")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(10, 20), (0, 10), (-20, -10)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.001
scheduler_gamma = 0.999
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.001, Gamma: 0.999")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(10, 20), (0, 10), (-20, -10)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.001
scheduler_gamma = 0.995
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.001, Gamma: 0.995")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(10, 20), (0, 10), (-20, -10)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.001
scheduler_gamma = 0.99
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.001, Gamma: 0.99")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 20), (0, 10), (-20, -5)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.001
scheduler_gamma = 0.985
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.001, Gamma: 0.985")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(8, 20), (0, 10), (-20, -5)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.001
scheduler_gamma = 0.99
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.001, Gamma: 0.99")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(8, 15), (0, 1), (-15, -8)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00003
#scheduler_gamma = 0.99
# scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(8, 20), (0, 1), (-20, -8)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00004
#scheduler_gamma = 0.99
# scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00004")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(8, 20), (0, 1), (-20, -8)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.000045
#scheduler_gamma = 0.99
# scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.000045")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(8, 20), (0, 1), (-20, -8)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
#scheduler_gamma = 0.99
# scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 20), (0, 1), (-20, -5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
scheduler_gamma = 0.993
scheduler_step_size = 1

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_step_size=scheduler_step_size)
df_default = summary_models.load_curves_df("LR: 0.001, Gamma: 0.993")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(7, 15), (0, 1), (-15, -7)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0001
scheduler_gamma = 0.5
scheduler_milestones = [350, 500, 800, 1200, 1500]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default_main = summary_models.load_curves_df("LR: 0.001, Milestones: [350, 500, 800, 1200, 1500]")
summary_models.plot_curves(df_default_main)
summary_models.plot_curves(df_default_main, ylims=[(7, 20), (0, 1), (-20, -7)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0001
scheduler_gamma = 0.5
scheduler_milestones = [350, 700, 1050, 1400, 1750]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default_2 = summary_models.load_curves_df("LR: 0.001, Milestones: [350, 700, 1050, 1400, 1750]")
summary_models.plot_curves(df_default_2)
summary_models.plot_curves(df_default_2, ylims=[(7, 20), (0, 1), (-20, -7)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00005
scheduler_gamma = 0.8
scheduler_milestones = [530, 1060, 1590]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, Milestones: [530, 1060, 1590]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(7, 20), (0, 1), (-20, -7)])

# %%
# Define the current setup
generative_dist = "Isotropic_Gaussian"
learning_rate = 0.00005
scheduler_gamma = 0.8
scheduler_milestones = [530, 1060, 1590]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate)
df_default_main = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default_main)
summary_models.plot_curves(df_default_main, ylims=[(5, 20), (0, 1), (-20, -5)])

# %% [markdown]
# # Compare the different model setups

# %%
df = pd.concat([df_default, df_default_main])
df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = ["LR: 0.00005, Milestones: [530, 1060, 1590]", "LR: 0.00005"]
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set")
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set")
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           ylims=[(5, 25), (0, 1), (-25, -5)])
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           ylims=[(5, 25), (0, 1), (-25, -5)])

# %% [markdown]
# # GMM - Learning Rate = 0.0001

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.0001
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, GMM_equally_weighted=GMM_equally_weighted,
                               learning_rate=learning_rate)
GMM_0_0001 = summary_models.load_curves_df("GMM LR: 0.0001")
summary_models.plot_curves(GMM_0_0001)
summary_models.plot_curves(GMM_0_0001, ylims=[(5, 25), (0, 1), (-25, -5)])

# %% [markdown]
# # GMM - Learning Rate = 0.0002

# %%
summary_models = SummaryModels(file_name, generative_dist=generative_dist, GMM_equally_weighted=GMM_equally_weighted,
                               learning_rate=0.0002)
GMM_0_0002 = summary_models.load_curves_df("GMM LR: 0.0002")
summary_models.plot_curves(GMM_0_0002)
summary_models.plot_curves(GMM_0_0002, ylims=[(5, 25), (0, 1), (-25, -5)])

# %% [markdown]
# # GMM - Learning Rate = 0.0003

# %%
summary_models = SummaryModels(file_name, generative_dist=generative_dist, GMM_equally_weighted=GMM_equally_weighted,
                               learning_rate=0.0003)
GMM_0_0003 = summary_models.load_curves_df("GMM LR: 0.0003")
summary_models.plot_curves(GMM_0_0003)
summary_models.plot_curves(GMM_0_0003, ylims=[(5, 25), (0, 1), (-25, -5)])

# %% [markdown]
# # GMM - Learning Rate = 0.00003

# %%
summary_models = SummaryModels(file_name, generative_dist=generative_dist, GMM_equally_weighted=GMM_equally_weighted,
                               learning_rate=0.00003)
GMM_0_00003 = summary_models.load_curves_df("GMM LR: 0.00003")
summary_models.plot_curves(GMM_0_00003)
summary_models.plot_curves(GMM_0_00003, ylims=[(5, 25), (0, 1), (-25, -5)])

# %%
scheduler_milestones = [700, 1000, 1200]
scheduler_gamma = 0.8
summary_models = SummaryModels(file_name, generative_dist=generative_dist, GMM_equally_weighted=GMM_equally_weighted,
                               learning_rate=0.00003, scheduler_milestones=scheduler_milestones, scheduler_gamma=scheduler_gamma)
GMM_0_00003_milestones = summary_models.load_curves_df("GMM LR: 0.00003, [700, 1000, 1200]")
summary_models.plot_curves(GMM_0_00003_milestones)
summary_models.plot_curves(GMM_0_00003_milestones, ylims=[(5, 25), (0, 1), (-25, -5)])

# %%
df = pd.concat([GMM_0_00003, GMM_0_00003_milestones])
df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = ["GMM LR: 0.00003", "GMM LR: 0.00003, [700, 1000, 1200]"]
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set")
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set")
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           ylims=[(5, 25), (0, 1), (-25, -5)])
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           ylims=[(5, 25), (0, 1), (-25, -5)])

# %% [markdown]
# # GMM - Learning Rate = 0.00004

# %%
summary_models = SummaryModels(file_name, generative_dist=generative_dist, GMM_equally_weighted=GMM_equally_weighted,
                               learning_rate=0.00004)
GMM_0_00004 = summary_models.load_curves_df("GMM LR: 0.00004")
summary_models.plot_curves(GMM_0_00004)
summary_models.plot_curves(GMM_0_00004, ylims=[(5, 25), (0, 1), (-25, -5)])

# %% [markdown]
# # GMM - Learning Rate = 0.00005

# %%
summary_models = SummaryModels(file_name, generative_dist=generative_dist, GMM_equally_weighted=GMM_equally_weighted,
                               learning_rate=0.00005)
GMM_0_00005 = summary_models.load_curves_df("GMM LR: 0.00005")
summary_models.plot_curves(GMM_0_00005)
summary_models.plot_curves(GMM_0_00005, ylims=[(5, 25), (0, 1), (-25, -5)])

# %%
df = pd.concat([GMM_0_0001, GMM_0_0002, GMM_0_0003, GMM_0_00003, GMM_0_00004, GMM_0_00005])
df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = ["GMM LR: 0.0001", "GMM LR: 0.0002", "GMM LR: 0.0003", "GMM LR: 0.00003", "GMM LR: 0.00004", "GMM LR: 0.00005"]
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set")
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set")
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           ylims=[(5, 25), (0, 1), (-25, -5)])
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           ylims=[(5, 25), (0, 1), (-25, -5)])

# %%
df = pd.concat([GMM_0_0001, GMM_0_00003, GMM_0_00004, GMM_0_00005])
df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = ["GMM LR: 0.0001", "GMM LR: 0.00003", "GMM LR: 0.00004", "GMM LR: 0.00005"]
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set")
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set")
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, title="Training data set",
                           ylims=[(5, 25), (0, 1), (-25, -5)])
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, title="Validation data set",
                           ylims=[(5, 25), (0, 1), (-25, -5)])

# %% [markdown]
# # Trajectory based reconstruction log probabilities
# Plot histograms of the validation trajectory based reconstruction log probabilities (by ship type)

# %%
#summary_models = SummaryModels(file_name)
#data = summary_models.run_evaluation()["TrajectoryLevelData"]
#x = "Reconstruction log probability"
#hue = "Ship type"
#hue_order = ["Cargo", "Tanker", "Fishing"]

# Plot trajectory based reconstruction log probabilities
#summary_models.hist_stacked_plot(data, type="Histogram", x=x, hue=hue, hue_order=hue_order)
#summary_models.hist_stacked_plot(data, type="Stacked", x=x, hue=hue, hue_order=hue_order)
#summary_models.hist_stacked_plot(data, type="Stacked", x=x, hue=hue, hue_order=hue_order,
#                                 stat="normalized_each_bin", ylabel="Stacked bin percentages", print_summary_stats=True)

# Zoom in 
#summary_models.hist_stacked_plot(data, type="Histogram", x=x, hue=hue, hue_order=hue_order, xlim=[-1000, 0])
#summary_models.hist_stacked_plot(data, type="Stacked", x=x, hue=hue, hue_order=hue_order, 
#                                 xlim=[-1000, 0], print_summary_stats=True)

# %% [markdown]
# # Equally weighted (point based) reconstruction log probabilities
# Divide the trajectory based reconstruction log probabilities by the corresponding trajectory length and plot the same histograms as above

# %%
#x = "Equally weighted reconstruction log probability"
#summary_models.hist_stacked_plot(data, type="Histogram", x=x, hue=hue, hue_order=hue_order)
#summary_models.hist_stacked_plot(data, type="Stacked", x=x, hue=hue, hue_order=hue_order)
#summary_models.hist_stacked_plot(data, type="Stacked", x=x, hue=hue, hue_order=hue_order,
#                                 stat="normalized_each_bin", ylabel="Stacked bin percentages", print_summary_stats=True)

# Zoom in 
#summary_models.hist_stacked_plot(data, type="Histogram", x=x, hue=hue, hue_order=hue_order, xlim=[-15, 0])
#summary_models.hist_stacked_plot(data, type="Stacked", x=x, hue=hue, hue_order=hue_order, 
#                                 xlim=[-15, 0], print_summary_stats=True)

# %%
# Look at some length statistics
# data.groupby("Ship type")["Length"].describe()
