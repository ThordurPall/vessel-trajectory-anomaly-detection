# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryModels import SummaryModels
import pandas as pd
file_name = "RegionBornholm_01062019_30092019_Fish_14400_86400_600"

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00001
use_generative_bias = True
first_order_diff = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
df_default_0_00001 = summary_models.load_curves_df("LR: 0.00001")
summary_models.plot_curves(df_default_0_00001)
summary_models.plot_curves(df_default_0_00001, ylims=[(4, 40), (0, 1), (-40, -4)])
summary_models.model_name
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\THORDU~1\AppData\Local\Temp/ipykernel_1392/870452867.py in <module>
#       8 summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
#       9                                use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
# ---> 10 df_default_0_00001 = summary_models.load_curves_df("LR: 0.00001")
#      11 summary_models.plot_curves(df_default_0_00001)
#      12 summary_models.plot_curves(df_default_0_00001, ylims=[(4, 40), (0, 1), (-40, -4)])
#
# c:\github\vessel-trajectory-anomaly-detection\src\visualisation\SummaryModels.py in load_curves_df(self, setup_type, validation_only, level)
#     325
#     326         # Read the file and setup the data frame
# --> 327         df = pd.read_csv(self.model_dir / curves_file)
#     328         if validation_only:
#     329             df_val = df.iloc[:, 0:3].copy()
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Github\\vessel-trajectory-anomaly-detection\\models\\saved-models\\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_GBT_FODT_lr1e-05_curves.csv'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00005
use_generative_bias = True
first_order_diff = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
df_default_0_00005 = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default_0_00005)
summary_models.plot_curves(df_default_0_00005, ylims=[(4, 40), (0, 1), (-40, -4)])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\THORDU~1\AppData\Local\Temp/ipykernel_1392/2206852487.py in <module>
#       8 summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
#       9                                use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
# ---> 10 df_default_0_00005 = summary_models.load_curves_df("LR: 0.00005")
#      11 summary_models.plot_curves(df_default_0_00005)
#      12 summary_models.plot_curves(df_default_0_00005, ylims=[(4, 40), (0, 1), (-40, -4)])
#
# c:\github\vessel-trajectory-anomaly-detection\src\visualisation\SummaryModels.py in load_curves_df(self, setup_type, validation_only, level)
#     325
#     326         # Read the file and setup the data frame
# --> 327         df = pd.read_csv(self.model_dir / curves_file)
#     328         if validation_only:
#     329             df_val = df.iloc[:, 0:3].copy()
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Github\\vessel-trajectory-anomaly-detection\\models\\saved-models\\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_GBT_FODT_lr5e-05_curves.csv'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0001
use_generative_bias = True
first_order_diff = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
df_default_0_0001 = summary_models.load_curves_df("LR: 0.0001")
summary_models.plot_curves(df_default_0_0001)
summary_models.plot_curves(df_default_0_0001, ylims=[(0, 40), (0, 1), (-40, 0)])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\THORDU~1\AppData\Local\Temp/ipykernel_1392/3189666495.py in <module>
#       8 summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
#       9                                use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
# ---> 10 df_default_0_0001 = summary_models.load_curves_df("LR: 0.0001")
#      11 summary_models.plot_curves(df_default_0_0001)
#      12 summary_models.plot_curves(df_default_0_0001, ylims=[(0, 40), (0, 1), (-40, 0)])
#
# c:\github\vessel-trajectory-anomaly-detection\src\visualisation\SummaryModels.py in load_curves_df(self, setup_type, validation_only, level)
#     325
#     326         # Read the file and setup the data frame
# --> 327         df = pd.read_csv(self.model_dir / curves_file)
#     328         if validation_only:
#     329             df_val = df.iloc[:, 0:3].copy()
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# C:\Anaconda\envs\MScThesis\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Github\\vessel-trajectory-anomaly-detection\\models\\saved-models\\VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_GBT_FODT_lr00001_curves.csv'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0005
use_generative_bias = True
first_order_diff = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
df_default_0_0005 = summary_models.load_curves_df("LR: 0.0005")
summary_models.plot_curves(df_default_0_0005)
summary_models.plot_curves(df_default_0_0005, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
use_generative_bias = True
first_order_diff = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.003
use_generative_bias = True
first_order_diff = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias, first_order_diff=first_order_diff)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Concat the different models
df = pd.concat([df_default_0_00001, df_default_0_00003, df_default_0_00005, df_default_0_0001, df_default_0_0005,
                df_default_0_0007, df_default_0_001, df_default_0_003, df_default_0_005])

df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = [
    "LR: 0.00001",
    "LR: 0.00003",
    "LR: 0.00005",
    "LR: 0.0001",
    "LR: 0.0005",
    "LR: 0.0007",
    "LR: 0.003",
    "LR: 0.005",
    "LR: 0.001",
]
x = "Number of optimiser steps"
ylims = [(4, 40), (0, 10), (-40, -4)]
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order,
                           title="Validation data set", ylims=[(-5, 40), (0, 1), (-40, 5)])
