# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryModels import SummaryModels
import pandas as pd
file_name = "RegionBornholm_01062019_30092019_Fish_14400_86400_600"

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00001
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_00001 = summary_models.load_curves_df("LR: 0.00001")
summary_models.plot_curves(df_default_0_00001)
summary_models.plot_curves(df_default_0_00001, ylims=[(4, 40), (0, 1), (-40, -4)])
summary_models.model_name
# Out:
# 'VRNN_RegionBornholm_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_GBT_lr1e-05'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00003
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_00003 = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default_0_00003)
summary_models.plot_curves(df_default_0_00003, ylims=[(4, 40), (0, 1), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00005
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_00005 = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default_0_00005)
summary_models.plot_curves(df_default_0_00005, ylims=[(4, 40), (0, 1), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0001
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_0001 = summary_models.load_curves_df("LR: 0.0001")
summary_models.plot_curves(df_default_0_0001)
summary_models.plot_curves(df_default_0_0001, ylims=[(0, 40), (0, 1), (-40, 0)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0005
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_0005 = summary_models.load_curves_df("LR: 0.0005")
summary_models.plot_curves(df_default_0_0005)
summary_models.plot_curves(df_default_0_0005, ylims=[(4, 40), (0, 1), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0007
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_0007 = summary_models.load_curves_df("LR: 0.0007")
summary_models.plot_curves(df_default_0_0007)
summary_models.plot_curves(df_default_0_0007, ylims=[(4, 40), (0, 1), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.003
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.005
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_005 = summary_models.load_curves_df("LR: 0.005")
summary_models.plot_curves(df_default_0_005)
summary_models.plot_curves(df_default_0_005, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Concat the different models
df = pd.concat([df_default_0_00001, df_default_0_00003, df_default_0_00005, df_default_0_0001, df_default_0_0005,
                df_default_0_0007, df_default_0_001, df_default_0_003, df_default_0_005])

df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = [
    "LR: 0.00001",
    "LR: 0.00003",
    "LR: 0.00005",
    "LR: 0.0001",
    "LR: 0.0005",
    "LR: 0.0007",
    "LR: 0.003",
    "LR: 0.005",
    "LR: 0.001",
]
x = "Number of optimiser steps"
ylims = [(4, 40), (0, 10), (-40, -4)]
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order,
                           title="Validation data set", ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Concat the different models
df = pd.concat([df_default_0_00005, df_default_0_0001, df_default_0_0005, df_default_0_001, df_default_0_003, df_default_0_005])

df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = [
    "LR: 0.00005",
    "LR: 0.0001",
    "LR: 0.0005",
    "LR: 0.003",
    "LR: 0.005",
    "LR: 0.001",
]
x = "Number of optimiser steps"
ylims = [(4, 40), (0, 10), (-40, -4)]
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order,
                           title="Validation data set", ylims=[(-5, 40), (0, 1), (-40, 5)])

# %% [markdown]
# # Adding milestones

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.003
scheduler_gamma = [0.7, 0.5, 0.6, 0.6]
scheduler_milestones = [50, 100, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003 ([0.7, 0.5, 0.6, 0.6])")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.003
scheduler_gamma = [0.5, 0.5, 0.6, 0.6]
scheduler_milestones = [50, 100, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003 ([0.5, 0.5, 0.6, 0.6])")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.003
scheduler_gamma = [0.4, 0.6, 0.6, 0.6]
scheduler_milestones = [50, 100, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003 ([0.4, 0.6, 0.6, 0.6])")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.003
scheduler_gamma = [0.4, 0.4, 0.5, 0.5]
scheduler_milestones = [50, 90, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003 ([0.4, 0.4, 0.5, 0.5])")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup - HERE?
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.003
scheduler_gamma = [0.6, 0.6, 0.5, 0.6, 0.6, 0.5, 0.5]
scheduler_milestones = [25, 50, 100, 150, 200, 250, 400]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003 ([0.6, 0.6, 0.5, 0.6, 0.6, 0.5, 0.5])")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.003
scheduler_gamma = [0.7, 0.5, 0.6, 0.6, 0.5, 0.5]
scheduler_milestones = [50, 100, 150, 200, 250, 400]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003 ([0.7, 0.5, 0.6, 0.6, 0.5, 0.5])")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.003
scheduler_gamma = [0.5, 0.6, 0.7, 0.6, 0.6, 0.5, 0.5]
scheduler_milestones =  [25, 50, 100, 150, 200, 250, 400]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003 ([25, 50, 100, 150, 200, 250, 400])")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.003
scheduler_gamma = [0.3, 0.6, 0.7, 0.6, 0.6, 0.5, 0.5]
scheduler_milestones =  [25, 50, 100, 150, 200, 250, 400]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003 ([25, 50, 100, 150, 200, 250, 400])")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.001
scheduler_gamma = [0.7, 0.5, 0.6, 0.6]
scheduler_milestones = [50, 100, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.7, 0.5, 0.6, 0.6])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.001
scheduler_gamma = [0.5, 0.5, 0.6, 0.6]
scheduler_milestones = [50, 100, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.5, 0.5, 0.6, 0.6])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.001
scheduler_gamma = [0.4, 0.6, 0.6, 0.6]
scheduler_milestones = [50, 100, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.5, 0.5, 0.6, 0.6])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.001
scheduler_gamma = [0.7, 0.4, 0.6, 0.6]
scheduler_milestones = [50, 90, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.7, 0.4, 0.6, 0.6])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.001
scheduler_gamma = [0.7, 0.3, 0.6, 0.6] 
scheduler_milestones = [50, 90, 150, 200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.7, 0.5, 0.6, 0.6])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.001
scheduler_gamma = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
scheduler_milestones = [50, 90, 150, 200, 400, 600]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.5, 0.5, 0.5, 0.5, 0.5, 0.5])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.001
scheduler_gamma = [0.4, 0.4, 0.5, 0.5, 0.5, 0.5]
scheduler_milestones = [50, 90, 150, 200, 400, 600]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.4, 0.4, 0.5, 0.5, 0.5, 0.5])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.0001
scheduler_gamma =  [0.7, 0.7, 0.7]
scheduler_milestones =  [180, 350, 700]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.0001 ( [180, 350, 700])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
use_generative_bias = True
learning_rate = 0.0001
scheduler_gamma =  [0.7, 0.7, 0.7, 0.7, 0.7, 0.7]
scheduler_milestones =  [200, 300, 400, 600, 800, 1200]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.0001 ([200, 300, 400, 600, 800, 1200])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
