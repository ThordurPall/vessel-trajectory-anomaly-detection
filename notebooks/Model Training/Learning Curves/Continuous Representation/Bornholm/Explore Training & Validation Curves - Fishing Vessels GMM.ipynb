# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryModels import SummaryModels
import pandas as pd
file_name = "RegionBornholm_01062019_30092019_Fish_14400_86400_600"

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# # Run 1: Epoch 650 - First milestone with gamma = 0.8 or 0.9

# %% [markdown]
# ## Gamma = 0.9 # Use this or even 0.8

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.8

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.7

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# # Run 2: Epoch 850 - Second milestone with gamma = 0.6 or 0.5

# %% [markdown]
# ## Gamma = 0.9

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.8

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.7

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# ## Gamma = 0.6 # Use this or gamma = 0.5

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -5)])

# %% [markdown]
# # Run 3: Epoch 1050 - Third milestone with gamma = 0.6 or 0.7

# %% [markdown]
# ## Gamma = 0.9

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -4)])

# %% [markdown]
# ## Gamma = 0.8

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -4)])

# %% [markdown]
# ## Gamma = 0.7

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(5, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False
scheduler_gamma = [0.8, 0.5, 0.6, 0.6]
scheduler_milestones = [650, 850, 1050, 1300]
GMM_components = 3

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted, scheduler_gamma=scheduler_gamma,
                               scheduler_milestones=scheduler_milestones, GMM_components=GMM_components)
df_default = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# %% [markdown]
# # Best one so far

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False
scheduler_gamma = [0.7, 0.5, 0.6, 0.6]
scheduler_milestones = [600, 800, 1000, 1300]
GMM_components = 4

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted, scheduler_gamma=scheduler_gamma,
                               scheduler_milestones=scheduler_milestones, GMM_components=GMM_components)
df_GMM_4 = summary_models.load_curves_df("GMM_4")
summary_models.plot_curves(df_GMM_4)
summary_models.plot_curves(df_GMM_4, ylims=[(4, 40), (0, 10), (-40, -4)])
df_GMM_4 = summary_models.load_curves_df("GMM_4", level="Step")

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False
scheduler_gamma = [0.7, 0.5, 0.6, 0.6]
scheduler_milestones = [600, 800, 1000, 1300]
GMM_components = 3

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted, scheduler_gamma=scheduler_gamma,
                               scheduler_milestones=scheduler_milestones, GMM_components=GMM_components)
df_GMM_3 = summary_models.load_curves_df("GMM_3")
summary_models.plot_curves(df_GMM_3)
summary_models.plot_curves(df_GMM_3, ylims=[(4, 40), (0, 10), (-40, -4)])

# %%
# Define the current setup
generative_dist = "GMM"
learning_rate = 0.00003
GMM_equally_weighted = False
scheduler_gamma = [0.7, 0.5, 0.6, 0.6]
scheduler_milestones = [600, 800, 1000, 1300]
GMM_components = 2

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               GMM_equally_weighted=GMM_equally_weighted, scheduler_gamma=scheduler_gamma,
                               scheduler_milestones=scheduler_milestones, GMM_components=GMM_components)
df_GMM_2 = summary_models.load_curves_df("GMM_2")
summary_models.plot_curves(df_GMM_2)
summary_models.plot_curves(df_GMM_2, ylims=[(4, 40), (0, 10), (-40, -4)])
df_GMM_2 = summary_models.load_curves_df("GMM_2", level="Step")

# %% [markdown]
# # Comparison

# %%
df_GMM_4 = df_GMM_4[:3160]
df_GMM_2 = df_GMM_2[:3160]
df_GMM_3['Epoch'] = df_GMM_4['Number of optimiser steps']
df_GMM_3.columns = df_GMM_4.columns
df = pd.concat([df_GMM_2, df_GMM_3, df_GMM_4])
df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = ["GMM_2", "GMM_3", "GMM_4"]
x="Number of optimiser steps"
ylims=[(4, 40), (0, 10), (-40, -4)]
xlims=[(0, 45000), (0, 45000), (0, 45000)]
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, x=x,
                           title="Training data set", ylims=ylims, xlims=xlims)
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, x=x,
                           title="Validation data set", ylims=ylims, xlims=xlims)

# %% [markdown]
# # Add the Diagonal Gaussian

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00005
scheduler_gamma = [0.5, 0.5, 0.7, 0.6]
scheduler_milestones = [500, 700, 1000, 1300]

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default = summary_models.load_curves_df("LR: 0.00005, [500, 700, 1000, 1300]")
summary_models.plot_curves(df_default)
summary_models.plot_curves(df_default, ylims=[(4, 40), (0, 10), (-40, -4)])

# Plot for the optimization steps
df_Diagonal = summary_models.load_curves_df("Diagonal", level="Step")
x="Number of optimiser steps"
summary_models.plot_curves(df_Diagonal, ylims=[(4, 40), (0, 10), (-40, -4)], x=x)

# %%
df_Diagonal = df_Diagonal[:3160]
df = pd.concat([df_GMM_2, df_GMM_3, df_GMM_4, df_Diagonal])
df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = ["GMM_2", "GMM_3", "GMM_4", "Diagonal"]
x="Number of optimiser steps"
ylims=[(4, 40), (0, 10), (-40, -4)]
xlims=[(0, 45000), (0, 45000), (0, 45000)]
summary_models.plot_curves(df[df["Data set type"] == "Training"], hue, hue_order, x=x,
                           title="Training data set", ylims=ylims, xlims=xlims)
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order, x=x,
                           title="Validation data set", ylims=ylims, xlims=xlims)
