# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryModels import SummaryModels
import pandas as pd
file_name = "RegionSkagen_01062019_30092019_Fish_14400_86400_600"

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00001
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_00001 = summary_models.load_curves_df("LR: 0.00001")
summary_models.plot_curves(df_default_0_00001)
summary_models.plot_curves(df_default_0_00001, ylims=[(4, 40), (0, 1), (-40, -4)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_GBT_lr1e-05'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00003
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_00003 = summary_models.load_curves_df("LR: 0.00003")
summary_models.plot_curves(df_default_0_00003)
summary_models.plot_curves(df_default_0_00003, ylims=[(4, 40), (0, 1), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00005
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_00005 = summary_models.load_curves_df("LR: 0.00005")
summary_models.plot_curves(df_default_0_00005)
summary_models.plot_curves(df_default_0_00005, ylims=[(4, 40), (0, 1), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0001
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_0001 = summary_models.load_curves_df("LR: 0.0001")
summary_models.plot_curves(df_default_0_0001)
summary_models.plot_curves(df_default_0_0001, ylims=[(4, 40), (0, 1), (-40, -4)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0005
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_0005 = summary_models.load_curves_df("LR: 0.0005")
summary_models.plot_curves(df_default_0_0005)
summary_models.plot_curves(df_default_0_0005, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0007
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_0007 = summary_models.load_curves_df("LR: 0.0007")
summary_models.plot_curves(df_default_0_0007)
summary_models.plot_curves(df_default_0_0007, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.003
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_003 = summary_models.load_curves_df("LR: 0.003")
summary_models.plot_curves(df_default_0_003)
summary_models.plot_curves(df_default_0_003, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.005
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                               use_generative_bias=use_generative_bias)
df_default_0_005 = summary_models.load_curves_df("LR: 0.005")
summary_models.plot_curves(df_default_0_005)
summary_models.plot_curves(df_default_0_005, ylims=[(-5, 40), (0, 1), (-40, 5)])

# %%
# Concat the different models
df = pd.concat([df_default_0_00001, df_default_0_00003, df_default_0_00005, df_default_0_0001, df_default_0_0005,
                df_default_0_0007, df_default_0_001, df_default_0_003, df_default_0_005])

df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = [
    "LR: 0.00001",
    "LR: 0.00003",
    "LR: 0.00005",
    "LR: 0.0001",
    "LR: 0.0005",
    "LR: 0.0007",
    "LR: 0.003",
    "LR: 0.005",
    "LR: 0.001",
]
x = "Number of optimiser steps"
ylims = [(-4, 40), (0, 10), (-40, 4)]
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order,
                           title="Validation data set", ylims=[(-4, 40), (0, 1), (-40, 4)])

# %%
# Concat the different models
df = pd.concat([df_default_0_0007, df_default_0_001, df_default_0_003, df_default_0_005])

df.reset_index(drop=True, inplace=True)
hue = "Setup type"
hue_order = [
    "LR: 0.0007",
    "LR: 0.003",
    "LR: 0.005",
    "LR: 0.001",
]
x = "Number of optimiser steps"
ylims = [(-4, 15), (0, 10), (-15, 4)]
summary_models.plot_curves(df[df["Data set type"] == "Validation"], hue, hue_order,
                           title="Validation data set", ylims=[(-4, 15), (0, 1), (-15, 4)])

# %% [markdown]
# # Adding milestones

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00001
scheduler_gamma = [0.5]
scheduler_milestones = [100]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default_0_00001_100 = summary_models.load_curves_df("LR: 0.00001 ([100])")
summary_models.plot_curves(df_default_0_00001_100)
summary_models.plot_curves(df_default_0_00001_100, ylims=[(3, 40), (0, 1), (-40, -3)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_lr1e-05_S100_05'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00003
scheduler_gamma = [0.3]
scheduler_milestones = [40]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default_0_00003_40 = summary_models.load_curves_df("LR: 0.00003 ([40])")
summary_models.plot_curves(df_default_0_00003_40)
summary_models.plot_curves(df_default_0_00003_40, ylims=[(3, 40), (0, 1), (-40, -3)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_lr3e-05_S40_03'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.00005
scheduler_gamma = [0.2]
scheduler_milestones = [35]


# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones)
df_default_0_00003_40 = summary_models.load_curves_df("LR: 0.00003 ([40])")
summary_models.plot_curves(df_default_0_00003_40)
summary_models.plot_curves(df_default_0_00003_40, ylims=[(3, 40), (0, 1), (-40, -3)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_lr5e-05_S35_02'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
scheduler_gamma = [0.8, 0.9, 0.8, 0.7, 0.7]
scheduler_milestones = [10, 20, 30, 40, 50]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.9, 0.8, 0.7, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_GBT_S1020304050_0809080707'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
scheduler_gamma = [0.8, 0.7]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_GBT_S2040_0807'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
scheduler_gamma = [0.7, 0.8]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.7, 0.8])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_latent100_recurrent100_batchNormFalse_Diagonal_GBT_S2040_0708'
