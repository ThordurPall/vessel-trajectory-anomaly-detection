# %%
# Loading the required packages to run this notebook
from src.visualisation.SummaryModels import SummaryModels
import pandas as pd
file_name = "RegionSkagen_01062019_30092019_Fish_14400_86400_600_02"

# %% [markdown]
# Filter by min speed = 0.2 knots

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0007
scheduler_gamma = [0.8, 0.7]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_02_latent100_recurrent100_batchNormFalse_Diagonal_GBT_lr00007_S2040_0807'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
scheduler_gamma = [0.8, 0.7]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_02_latent100_recurrent100_batchNormFalse_Diagonal_GBT_S2040_0807'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.005
scheduler_gamma = [0.8, 0.7]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_02_latent100_recurrent100_batchNormFalse_Diagonal_GBT_lr0005_S2040_0807'

# %% [markdown]
# Filter by min speed = 0.6 knots

# %%
file_name = "RegionSkagen_01062019_30092019_Fish_14400_86400_600_06"

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
scheduler_gamma = [0.8, 0.7]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_06_latent100_recurrent100_batchNormFalse_Diagonal_GBT_S2040_0807'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.001
scheduler_gamma = [0.7, 0.8]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_06_latent100_recurrent100_batchNormFalse_Diagonal_GBT_S2040_0708'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.0007
scheduler_gamma = [0.8, 0.7]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_06_latent100_recurrent100_batchNormFalse_Diagonal_GBT_lr00007_S2040_0807'

# %%
# Define the current setup
generative_dist = "Diagonal"
learning_rate = 0.005
scheduler_gamma = [0.8, 0.7]
scheduler_milestones = [20, 40]
use_generative_bias = True

# Use the SummaryModels class
summary_models = SummaryModels(file_name, generative_dist=generative_dist, learning_rate=learning_rate,
                              scheduler_gamma=scheduler_gamma, scheduler_milestones=scheduler_milestones,
                              use_generative_bias=use_generative_bias)
df_default_0_001 = summary_models.load_curves_df("LR: 0.001 ([0.8, 0.7])")
summary_models.plot_curves(df_default_0_001)
summary_models.plot_curves(df_default_0_001, ylims=[(-5, 40), (0, 1), (-40, 5)])
summary_models.model_name
# Out:
# 'VRNN_RegionSkagen_01062019_30092019_Fish_14400_86400_600_06_latent100_recurrent100_batchNormFalse_Diagonal_GBT_lr0005_S2040_0807'
